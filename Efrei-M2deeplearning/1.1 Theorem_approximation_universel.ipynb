# %% [markdown]
# # Theoreme approximation universel
#
# Le théorème d'approximation universel stipule que pour toute fonction on peut construire un réseau de neurone qui en effectue l'approximation avec une certaines précision. Plus le réseau de neurone est gros meilleur l'approximation sera
#
#
# L'objectif de ce notebook est d'observer le phénomène et de voir ce qui est nécessaire pour qu'il advienne

# %% [markdown]
# Charger le dataset func1.csv qui contient des valeurs et les valeurs d'une fonction correspondante

# %% [markdown]
# Avec matplotlib tracer le graphe de la fonction

# %% [markdown]
# Charger et tracer le dataset de func2.csv

# %% [markdown]
# Quelle fonction vous parait la plus simple ?

# %% [markdown]
# ## Réseaux de neurones sans fonction d'activation

# %% [markdown]
# Faire un réseau à deux couches sans fonction d'activation.
# Pour cela vous pouvez utilisez activation="linear"

# %% [markdown]
# Compiler le modèle avec la bonne loss et l'optimiser sgd ou adam

# %% [markdown]
# Entraîner le modèle

# %% [markdown]
# Afficher la loss du modèle

# %% [markdown]
# Superposer les prédiction du modèle avec le graphe de la première fonction

# %% [markdown]
# Faire de même avec la fonction 2

# %% [markdown]
# Proposez une explication sur la différence de résultats

# %% [markdown]
# ## Réseaux de neurones avec fonction d'activation

# %% [markdown]
# Entraîner maintenant un réseau avec une fonction d'activitation relu sur func2 . Les résultats sont-ils meilleurs ?

# %% [markdown]
# Créer une fonction def complex_math_function() avec une formule mélangeant cosinus, exponentielle, polynomes etc.

# %% [markdown]
# Entraîner une série de réseau progressivement de plus en plus gros jusqu'à ce que le modèle arrive à approximer votre fonction.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6b859965-b858-4b8d-a841-009599aef86e' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
