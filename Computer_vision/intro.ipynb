# %%
# download a picture of a cat
# and display it
import requests
from PIL import Image
from io import BytesIO
def get_cat():
    url = 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Cat03.jpg/1200px-Cat03.jpg'
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    return img

# %%
cat = get_cat()

# %%
from numpy import array

arr_cat = array(cat)

# %%
arr_cat
# Out:
# array([[[218, 209, 176],
#         [217, 208, 175],
#         [216, 207, 176],
#         ...,
#         [230, 220, 208],
#         [230, 220, 208],
#         [230, 220, 208]],
#
#        [[218, 209, 176],
#         [217, 208, 175],
#         [216, 207, 176],
#         ...,
#         [231, 221, 209],
#         [231, 221, 209],
#         [231, 221, 209]],
#
#        [[218, 209, 176],
#         [216, 207, 174],
#         [216, 207, 174],
#         ...,
#         [232, 222, 210],
#         [232, 222, 210],
#         [232, 222, 210]],
#
#        ...,
#
#        [[182, 152, 118],
#         [182, 152, 118],
#         [184, 154, 120],
#         ...,
#         [226, 214, 198],
#         [226, 214, 198],
#         [225, 213, 197]],
#
#        [[181, 151, 117],
#         [182, 152, 118],
#         [183, 153, 119],
#         ...,
#         [227, 215, 199],
#         [226, 214, 198],
#         [225, 213, 197]],
#
#        [[181, 151, 117],
#         [182, 152, 118],
#         [183, 153, 119],
#         ...,
#         [226, 214, 198],
#         [226, 214, 198],
#         [225, 213, 197]]], dtype=uint8)

# %%
grayscale = cat.convert('L')

# %%
grayscale
# Out:
# <PIL.Image.Image image mode=L size=1200x1199>
